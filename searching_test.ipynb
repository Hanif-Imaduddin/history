# %%
import urllib.parse

# %%
# Out:
# 'https://www.google.com/search?q=EdTech%20customer%20acquisition%20cost%20CAC%20conversion%20rate%20Indonesia%20Southeast%20Asia%2020&num=5'

# %%
import requests

headers = {
    "Authorization": "Bearer 5ab86570-044e-46d6-9a08-5e95fd65ede6",
    "Content-Type": "application/json"
}
data = {
    "zone": "serp_api_capstone",
    "url": f"https://www.google.com/search?q={urllib.parse.quote('EdTech customer acquisition cost CAC conversion rate Indonesia Southeast Asia 2023')}&num=5",
    "format": "json"
}

response = requests.post(
    "https://api.brightdata.com/request",
    json=data,
    headers=headers
)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import json

# %%
response_json = response.json()

# %%
result = json.loads(response_json['body'])

# %%
result.keys()
# Out:
# dict_keys(['general', 'input', 'navigation', 'organic', 'pagination', 'related', 'people_also_ask'])

# %%
result['organic']
# Out:
# [{'link': 'https://www.unileverfoodsolutions.co.id/id/inspirasi-chef/jajanan-kekinian-yang-lagi-viral.html',
#   'source': 'unileverfoodsolutions.co.id',
#   'display_link': 'https://www.unileverfoodsolutions.co.id › ...',
#   'title': '20 Jajanan Kekinian yang Lagi Viral Untuk Ide Jualan for ...',
#   'description': 'Poles nasi jinggo menjadi lebih modern sebagai ide jualan kekinian. Anda dapat mengemasnya dengan porsi yang lebih variatif atau pilihan lauk premium seperti ...Read more',
#   'snippet_highlighted_words': ['Poles nasi jinggo'],
#   'icon': 'data:image/png;base64,...',
#   'rank': 1,
#   'global_rank': 1},
#  {'link': 'https://www.lalamove.com/id/blog/ide-bisnis-makanan-viral/',
#   'source': 'Lalamove',
#   'display_link': 'https://www.lalamove.com › blog',
#   'title': 'Ide Makanan Viral untuk Bisnis Kuliner yang Menguntungkan',
# ...
