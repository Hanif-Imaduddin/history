# %%
import requests

headers = {
    "Authorization": "Bearer 5ab86570-044e-46d6-9a08-5e95fd65ede6",
    "Content-Type": "application/json"
}
data = {
    "zone": "serp_api_capstone",
    "url": "https://www.google.com/search?q=ide+bisnis+kuliner+jakarta+viral",
    "format": "json"
}

response = requests.post(
    "https://api.brightdata.com/request",
    json=data,
    headers=headers
)

# %%
import json

# %%
response_json = response.json()

# %%
result = json.loads(response_json['body'])

# %%
result.keys()
# Out:
# dict_keys(['general', 'input', 'navigation', 'organic', 'videos', 'pagination', 'related', 'people_also_ask'])

# %%
result['organic']
# Out:
# [{'link': 'https://www.unileverfoodsolutions.co.id/id/inspirasi-chef/jajanan-kekinian-yang-lagi-viral.html',
#   'source': 'unileverfoodsolutions.co.id',
#   'display_link': 'https://www.unileverfoodsolutions.co.id › ...',
#   'title': 'Jajanan Kekinian yang Lagi Viral untuk Ide Jualan di Jakarta',
#   'description': 'Poles nasi jinggo menjadi lebih modern sebagai ide jualan kekinian. Anda dapat mengemasnya dengan porsi yang lebih variatif atau pilihan lauk premium seperti ...',
#   'snippet_highlighted_words': ['Poles nasi jinggo'],
#   'icon': 'data:image/png;base64,...',
#   'rank': 1,
#   'global_rank': 8},
#  {'link': 'https://www.lalamove.com/id/blog/bisnis-kuliner-modal-kecil/',
#   'source': 'Lalamove',
#   'display_link': 'https://www.lalamove.com › blog',
#   'title': '23 Ide Bisnis Kuliner Modal Kecil Tapi Cuan Besar!',
#   'description': 'Ide Jualan Makanan yang Mudah Dibuat · Donat Kentang · Pisang Goreng Kriuk · Dessert Box · Smoothie Buah dan Sayur.',
#   'snippet_highlighted_words': ['Donat Kentang'],
#   'icon': 'data:image/png;base64,...',
#   'rank': 2,
#   'global_rank': 9},
#  {'link': 'https://www.tempo.co/ekonomi/13-jenis-bisnis-kuliner-yang-kekinian-dan-populer-di-sosial-media-111758',
#   'source': 'Tempo.co',
#   'display_link': 'https://www.tempo.co › ... › Bisnis',
#   'title': '13 Jenis Bisnis Kuliner yang Kekinian dan Populer di ...',
#   'description': 'Ide Bisnis Kuliner yang Kekinian dan Populer · 1. Cromboloni · 2. Bomboloni · 3. Es Kul Kul · 4. Mile Crepes · 5. Bruule Bomb · 6. Dessert Box · 7.',
#   'snippet_highlighted_words': ['1. Cromboloni'],
#   'extensions': [{'inline': True,
#     'type': 'text',
#     'text': '6 Dec 2023',
#     'rank': 1}],
#   'icon': 'data:image/png;base64,...',
#   'rank': 3,
#   'global_rank': 10},
#  {'link': 'https://www.nibble.id/kuliner-viral-jakarta-selatan-2024/',
#   'source': 'nibble.id',
#   'display_link': 'https://www.nibble.id › kuliner-vir...',
#   'title': '10 Kuliner Viral Jakarta Selatan 2024 yang Bikin FOMO - Nibble',
#   'description': 'Ada cafe bakery terbaru nih yang buka 2023 dan masih hits dengan konsep kekinian di Kemang Jakarta Selatan. Namanya adalah Sesame Bakery Room ...',
#   'snippet_highlighted_words': ['Jakarta'],
#   'extensions': [{'inline': True,
#     'type': 'text',
#     'text': '15 May 2024',
#     'rank': 1}],
#   'icon': 'data:image/png;base64,...',
#   'rank': 4,
#   'global_rank': 11},
#  {'link': 'https://www.cimbniaga.co.id/id/inspirasi/gayahidup/street-food',
#   'source': 'CIMB Niaga',
#   'display_link': 'https://www.cimbniaga.co.id › stre...',
#   'title': '15 Daftar Street Food Indonesia, Bisa Jadi Peluang Usaha!',
#   'description': '15 Daftar Street Food Indonesia Populer · Siomay · Batagor · Pempek · Bubur Ayam · Nasi Uduk · Serabi · Pisang Goreng · Tempe Mendoan.',
#   'snippet_highlighted_words': ['Siomay'],
#   'icon': 'data:image/jpeg;base64,...',
#   'rank': 5,
#   'global_rank': 12},
#  {'link': 'https://www.havehalalwilltravel.com/id/selebgram-bisnis-kuliner-makanan-viral',
#   'source': 'Have Halal Will Travel',
#   'display_link': 'https://www.havehalalwilltravel.com › ...',
#   'title': 'Selebgram Bisnis Kuliner, Yang Mana Favorit Kamu?',
#   'description': 'Baru-baru ini, Fadil Jaidi membuka bisnis makanan Traffic Bun yang sukses trending di sosial media. Sebelum Fadil Jaidi dan Traffic Bun, ada banyak selebgram ...',
#   'snippet_highlighted_words': ['Traffic Bun'],
#   'icon': 'data:image/png;base64,...',
#   'rank': 6,
#   'global_rank': 13},
#  {'link': 'https://www.instagram.com/jktfoodbang/',
#   'source': 'Instagram · jktfoodbang',
#   'display_link': '1.3M+ followers',
#   'title': 'JAKARTA FOOD BANGERS (@jktfoodbang)',
#   'description': 'Kuliner Viral Indonesia | Food Content Creator. Kuliner Viral Indonesia | Food Content Creator ... Kuliner Bintaro Tangsel dan Jakarta. Follow.',
#   'snippet_highlighted_words': ['Kuliner Viral Indonesia'],
#   'extensions': [{'type': 'missing', 'text': 'bisnis', 'rank': 1},
#    {'type': 'must_include',
#     'text': 'bisnis',
#     'link': 'https://www.google.com/search?sca_esv=09173728c48945df&hl=en&q=ide+%22bisnis%22+kuliner+jakarta+viral&sa=X&ved=2ahUKEwj7ouechf-TAxXUVEEAHW-bOiIQ5t4CegQIShAB',
#     'rank': 2}],
#   'icon': 'data:image/png;base64,...',
#   'rank': 7,
#   'global_rank': 14},
#  {'link': 'https://www.liputan6.com/hot/read/6320336/15-ide-bisnis-snack-kiloan-di-kontrakan-sempit-janjikan-keuntungan-besar',
#   'source': 'Liputan6.com',
#   'display_link': 'https://www.liputan6.com › Hot',
#   'title': '15 Ide Bisnis Snack Kiloan di Kontrakan Sempit, Janjikan ...',
#   'description': 'Snack repackaging seperti Chiki atau Cheetos bisa menjadi peluang bisnis dengan modal kecil. Produk dibeli dalam jumlah besar lalu dikemas ulang ...',
#   'snippet_highlighted_words': ['Snack repackaging seperti Chiki atau Cheetos'],
#   'extensions': [{'inline': True,
#     'type': 'text',
#     'text': '5 hours ago',
#     'rank': 1},
#    {'inline': True, 'type': 'text', 'text': '', 'rank': 2}],
#   'icon': 'data:image/png;base64,...',
#   'rank': 8,
#   'global_rank': 15},
#  {'link': 'https://www.bee.id/blog/usaha-makanan-kekinian/',
#   'source': 'Bee.id',
#   'display_link': 'https://www.bee.id › Blog › F&B',
#   'title': '17+ Ide Usaha Makanan Kekinian yang Lagi Viral 2024',
#   'description': 'Rekomendasi Ide Usaha Makanan Kekinian · 1. Keripik Pedas · 2. Nasi Cokot/ Nasi Gigit · 3. Croffle · 4. Boba Drinks · 5. Kue Balok Lumer · 6. Dessert ...',
#   'snippet_highlighted_words': ['1. Keripik Pedas'],
#   'extensions': [{'inline': True,
#     'type': 'text',
#     'text': '13 Feb 2024',
#     'rank': 1}],
#   'icon': 'data:image/png;base64,...',
#   'rank': 9,
#   'global_rank': 16}]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
